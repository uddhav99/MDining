# %%
from bs4 import BeautifulSoup
import requests
r = requests.get("https://dining.umich.edu/menus-locations/dining-halls/bursley/?menuDate=2019-02-12")
soup = BeautifulSoup(r.text, "html5lib")
    
#items = soup.select(".item-name")
traits = soup.select(".traits")

#for i in range(0,len(items)):
    #print(items[i].text.strip())
    #print((traits[i+1].text.strip()))
    #print("\n")
    
item = soup.select("ul.items > li")
print(len(item))
for i in range(0, len(item)):
    name = item[i].select('.item-name')
#     trait = item[i].select('.traits')
    print(traits[1].text.strip())
    print(name[0].text)
# Out:
# 112
# Vegan
# Grits
# Vegan
# Oatmeal
# Vegan
# Breakfast Sandwich To Order
# Vegan
# Strawberry Pancakes
# Vegan
# Chicken Sausage Patties
# Vegan
# Hash Browns
# Vegan
# Breakfast Burrito with Sausage
# Vegan
# Scrambled Tofu
# Vegan
# Scrambled Eggs
# Vegan
# Ham & Cheese Omelette
# Vegan
# Cheese Omelette
# Vegan
# Iced Chocolate Long John
# Vegan
# Apple Cinnamon Muffins
# Vegan
# Mini Assorted Danishes
# Vegan
# Italian Wedding Soup
# Vegan
# Sweet Potato Soup
# Vegan
# Georgia Reuben
# Vegan
# Sandwiches Made to Order
# Vegan
# Bo Luc Lac
# Vegan
# Jasmine Rice
# Vegan
# Pickled Vegetables
# Vegan
# Sliced Tomatoes
# Vegan
# Sliced Red Onions
# Vegan
# Sliced Cucumbers
# Vegan
# Bibb Lettuce
# Vegan
# Tempeh Vietnamese Chili Stir Fry
# Vegan
# Pickled Vegetables
# Vegan
# Cherry Glazed Tofu
# Vegan
# Quinoa Salad with Chickpeas and Almonds
# Vegan
# Roasted Broccoli
# Vegan
# Provolone Sweet Potato Curry Burger
# Vegan
# Cornflake Chicken
# Vegan
# Belgian Waffles
# Vegan
# Syrup
# Vegan
# Fresh Strawberries
# Vegan
# Powdered Sugar
# Vegan
# Gemelli with Marinara Sauce
# Vegan
# Broccoli Alfredo Pizza
# Vegan
# Cheese Bread
# Vegan
# Cheese Pizza
# Vegan
# Pepperoni Pizza
# Vegan
# Beef & Mushroom Blended Burger w/ Cheese
# Vegan
# Hamburger on White Bun
# Vegan
# Cheeseburger on White Bun
# Vegan
# Beef Hot Dog
# Vegan
# Pork Bulgogi
# Vegan
# Korean Sweet and Spicy Sauce
# Vegan
# Tofu
# Vegan
# Beef Strips
# Vegan
# Mongolian Sauce
# Vegan
# Decadence Brownie
# Vegan
# German Choc Cake Coconut, Pecan, Walnut
# Vegan
# Vegan Brownie with Almond & Cocoa Icing
# Vegan
# Chocolate Chunk Cookies
# Vegan
# Lemon Zest Cookies
# Vegan
# Italian Wedding Soup
# Vegan
# Sweet Potato Soup
# Vegan
# Sandwiches Made to Order
# Vegan
# Broccoli Alfredo Pizza
# Vegan
# Cheese Bread
# Vegan
# Cheese Pizza
# Vegan
# Pepperoni Pizza
# Vegan
# Beef & Mushroom Blended Burger w/ Cheese
# Vegan
# Hamburger on White Bun
# Vegan
# Cheeseburger on White Bun
# Vegan
# Beef Hot Dog
# Vegan
# Vegan Brownie with Almond & Cocoa Icing
# Vegan
# Chocolate Chunk Cookies
# Vegan
# Lemon Zest Cookies
# Vegan
# Italian Wedding Soup
# Vegan
# Sweet Potato Soup
# Vegan
# Sandwiches Made to Order
# Vegan
# Puerto Rican Pork Roast
# Vegan
# Red Beans & Rice
# Vegan
# Grape Tomatoes
# Vegan
# Corn with Cumin, Chili, and Tomato
# Vegan
# Avocado Wedge
# Vegan
# Red Beans & Rice
# Vegan
# Grape Tomatoes
# Vegan
# Corn with Cumin, Chili, and Tomato
# Vegan
# Avocado Wedge
# Vegan
# Stuffed Cabbage with Lentils
# Vegan
# Roasted Garlic Smashed Yukon Potatoes
# Vegan
# Parsley
# Vegan
# Roasted Broccoli
# Vegan
# Provolone Sweet Potato Curry Burger
# Vegan
# Baked Halal Chicken
# Vegan
# Roasted Red Pepper Cream Sauce
# Vegan
# Parmesan Roasted Potatoes
# Vegan
# Herbed Provence Green Beans
# Vegan
# Gemelli with Marinara Sauce
# Vegan
# Broccoli Alfredo Pizza
# Vegan
# Cheese Bread
# Vegan
# Cheese Pizza
# Vegan
# Pepperoni Pizza
# Vegan
# Beef & Mushroom Blended Burger w/ Cheese
# Vegan
# Hamburger on White Bun
# Vegan
# Cheeseburger on White Bun
# Vegan
# Beef Hot Dog
# Vegan
# Coconut Pound Cake
# Vegan
# Lemon Cream Pie
# Vegan
# Turtle Cheesecake with Pecans
# Vegan
# Sandwiches Made to Order
# Vegan
# Broccoli Alfredo Pizza
# Vegan
# Cheese Bread
# Vegan
# Cheese Pizza
# Vegan
# Pepperoni Pizza
# Vegan
# Beef & Mushroom Blended Burger w/ Cheese
# Vegan
# Hamburger on White Bun
# Vegan
# Cheeseburger on White Bun
# Vegan
# Beef Hot Dog
# Vegan
# Turtle Cheesecake with Pecans

# %%
with open("file.html", "w") as f:
    f.write(r.text)

# %%
s = 0
for i in (soup.select("ul.items")):
    items = i.select("li a .")
    s += (len(items))
print(s)
# Out:
# Traceback (most recent call last):
#
#   File "/Users/uddhavbhagat/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-185-8f3bc478bb2f>", line 3, in <module>
#     items = i.select("li a .")
#
#   File "/Users/uddhavbhagat/opt/anaconda3/lib/python3.7/site-packages/bs4/element.py", line 1334, in select
#     return soupsieve.select(selector, self, namespaces, limit, **kwargs)
#
#   File "/Users/uddhavbhagat/opt/anaconda3/lib/python3.7/site-packages/soupsieve/__init__.py", line 114, in select
#     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#
#   File "/Users/uddhavbhagat/opt/anaconda3/lib/python3.7/site-packages/soupsieve/__init__.py", line 63, in compile
#     return cp._cached_css_compile(pattern, namespaces, custom, flags)
#
#   File "/Users/uddhavbhagat/opt/anaconda3/lib/python3.7/site-packages/soupsieve/css_parser.py", line 205, in _cached_css_compile
#     CSSParser(pattern, custom=custom_selectors, flags=flags).process_selectors(),
#
#   File "/Users/uddhavbhagat/opt/anaconda3/lib/python3.7/site-packages/soupsieve/css_parser.py", line 1064, in process_selectors
#     return self.parse_selectors(self.selector_iter(self.pattern), index, flags)
#
#   File "/Users/uddhavbhagat/opt/anaconda3/lib/python3.7/site-packages/soupsieve/css_parser.py", line 915, in parse_selectors
#     key, m = next(iselector)
#
#   File "/Users/uddhavbhagat/opt/anaconda3/lib/python3.7/site-packages/soupsieve/css_parser.py", line 1057, in selector_iter
#     raise SelectorSyntaxError(msg, self.pattern, index)
#
#   File "<string>", line unknown
# SelectorSyntaxError: Malformed class selector at position 5
#   line 1:
# li a .
#      ^

# %%
str(datetime.datetime(2018, 1, 1).date())
# Out:
# '2018-01-01'

# %%
import datetime

import pandas as pd
import requests
from bs4 import BeautifulSoup

menu_items = dict()
meal_items = []



dining_halls = ["bursley", "east-quad", "markley", "mosher-jordan", "north-quad", "south-quad", "twigs-at-oxford"] #list of dining halls
dates = pd.date_range(datetime.datetime(2020, 2, 12), datetime.datetime.today()).tolist()
for date in dates:
    for dh in dining_halls:
        r = requests.get("https://dining.umich.edu/menus-locations/dining-halls/{}/?menuDate={}".format(dh, str(date.date())))
        soup = BeautifulSoup(r.text, "html5lib")
        print("Parsing {} {}".format(dh, str(date.date())))
        items = soup.select("ul.items > li")
        for item in items:
            name = item.select('.item-name')[0].text
            # add {item, dining hall, meal, date} to meal_items
            meal_items.append({
                "date": str(date.date()),
                "dining_hall": dh,
                "meal": None,
                "item": name
            })
            if name not in items:
                # add {item, nutrition, other attrs} info to dict
                menu_items[name] = dict()
                for tr in item.select(".nutrition-wrapper tr"):
                    if "Serving Size" in tr.text:
                        menu_items[name]["serving_size"] = " ".join(tr.text.split()[2:])
                    if "Calories" in tr.text:
                        menu_items[name]["calories"] = "".join(tr.text.split()[1:])
                    if "Total Fat" in tr.text:
                        menu_items[name]["total fat"] = "".join(tr.text.split()[2:3])
                    if "Cholestrol" in tr.text:
                        menu_items[name]["cholestrol"] = "".join(tr.text.split()[1:2])
                    if "Sodium" in tr.text:
                        menu_items[name]["sodium"] = "".join(tr.text.split()[1:2])
                    if "Total Carbohydrate" in tr.text:
                        menu_items[name]["carbs"] = "".join(tr.text.split()[2:3])
                    if "Dietary Fiber" in tr.text:
                        menu_items[name]["fiber"] = "".join(tr.text.split()[2:3])
                    if "Sugars" in tr.text:
                        menu_items[name]["sugar"] = "".join(tr.text.split()[1:2])
                    if "Protein" in tr.text:
                        menu_items[name]["protein"] = "".join(tr.text.split()[1:2])
                    if "Calcium" in tr.text:
                        menu_items[name]["calcium"] = "".join(tr.text.split()[1:])
                    if "Iron" in tr.text:
                        menu_items[name]["iron"] = "".join(tr.text.split()[1:])
                    if "Vitamin A" in tr.text:
                        menu_items[name]["vitaminA"] = "".join(tr.text.split()[2:])
                    if "Vitamin C" in tr.text:
                        menu_items[name]["vitaminC"] = "".join(tr.text.split()[2:])
# Out:
# Parsing bursley 2020-02-12
# Parsing east-quad 2020-02-12
# Parsing markley 2020-02-12
# Parsing mosher-jordan 2020-02-12
# Parsing north-quad 2020-02-12
# Parsing south-quad 2020-02-12
# Parsing twigs-at-oxford 2020-02-12

# %%
menu_items
R = pd.DataFrame(menu_items).T

# %%
R.head(10)
# Out:
#                                          serving_size calories total fat  \
# Grits                                     Cups (254g)      225        2g
# Oatmeal                                   Cups (253g)      161        3g
# Breakfast Sandwich To Order           Sandwich (152g)      358       21g
# Strawberry Pancakes                     Pancake (45g)       67        1g
# Chicken Sausage Patties                   Patty (43g)       81        6g
# Hash Browns                             1/2 Cup (91g)       73        2g
# Breakfast Burrito with Sausage         Burrito (108g)      315       21g
# Scrambled Tofu                         1/2 Cup (113g)      138        8g
# Scrambled Eggs                  1/2 cup Serving (84g)      157       12g
# Ham & Cheese Omelette                 Omelette (142g)      270       20g
#
#                                sodium carbs fiber sugar protein vitaminA  \
# Grits                           706mg   47g    3g    0g      5g       0%
# Oatmeal                           3mg   29g    4g    0g      6g       0%
# Breakfast Sandwich To Order     808mg   24g    1g    3g     19g      12%
# Strawberry Pancakes             296mg   14g    1g    3g      2g       0%
# Chicken Sausage Patties         273mg    0g    0g    0g      6g       0%
# Hash Browns                     109mg   12g    2g    0g      3g       0%
# Breakfast Burrito with Sausage  479mg   16g    1g    1g     14g      10%
# Scrambled Tofu                  253mg    5g    1g    1g     11g       1%
# Scrambled Eggs                  127mg    0g    0g    0g     11g       7%
# Ham & Cheese Omelette           582mg    1g    0g    1g     22g      14%
#
#                                vitaminC calcium iron
# Grits                                0%      0%  10%
# Oatmeal                              0%      2%  10%
# Breakfast Sandwich To Order          1%     20%  16%
# Strawberry Pancakes                  3%      0%   0%
# Chicken Sausage Patties              2%      0%   5%
# Hash Browns                         18%      3%  15%
# Breakfast Burrito with Sausage      16%     13%  13%
# Scrambled Tofu                      10%      9%  10%
# Scrambled Eggs                       0%      4%  10%
# Ham & Cheese Omelette                0%     21%  13%

# %%
R.dtypes
# Out:
# serving_size    object
# calories        object
# total fat       object
# sodium          object
# carbs           object
# fiber           object
# sugar           object
# protein         object
# vitaminA        object
# vitaminC        object
# calcium         object
# iron            object
# dtype: object
